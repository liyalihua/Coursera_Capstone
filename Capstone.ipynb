# %% [markdown]
# #

# %% [markdown]
# # Capstone project

# %%
print("Hello Capstone Project Course")
# Out:
# Hello Capstone Project Course

# %% [markdown]
# ## 0. library

# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# ## 1. Data Colleciton
# Location Data is used in this project. We have chosen Foursquare as our data provider. For further development features of location data should be taken into account.
#
# A. Location Data Providers:
#
# 1. Foursquare
# 2. Google places
# 3. yelp
# 4. etc
#
# B. Features:
#
#
# 1. Rate Limits
# 2. Cost
# 3. Coverage
# 4. Accuracy
# 5. Update Frequency
